# %% [markdown]
# <a href="https://colab.research.google.com/github/larrymoreorless/Machine-Learning/blob/master/single_digit_mnst_classifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline


#Load the MNIST Data set, split it into training and test sets, and convert it to 2D
from keras.datasets import mnist

(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

train_images = train_images.reshape((60000, 28 * 28))
train_images = train_images.astype('float32') / 255

test_images = test_images.reshape((10000, 28 * 28))
test_images = test_images.astype('float32') / 255


#Can manipulate this digit variable to test the model for each or the 10 digits
digit = 9


#Convert training and test labels to binary
for i in range(len(test_labels)):
    if test_labels[i] == digit:
        test_labels[i] = 1
    else:
        test_labels[i] = 0
 
for i in range(len(train_labels)):
    if train_labels[i] == digit:
        train_labels[i] = 1
    else:
        train_labels[i] = 0


s = np.random.permutation(len(train_labels))
train_labels[s[i]]


    
#Sigmoid activation function
def sigmoid(x):
    return 1 / (1 + np.exp(-x))


#Set initial model params and calculate gradient using LA
batch_size = 5000
epochs = 10
lr = 0.01
np.random.seed(42)
initial_weight = np.random.randn(784) #for problem 3, do the same thing for 10, 28, 28 matrix (10,784) or (784, 10)
weight = initial_weight
n = len(train_images)
b = np.random.random_sample()

#MSE Loss Function
for epoch in range(epochs):
    for i in range(batch_size):
        offset = epoch * batch_size + i
        xi = train_images[s[offset]]
        yi = train_labels[s[offset]]
        z = xi.T.dot(weight) + b
        a = sigmoid(z)
        w_gradient = (a-yi)*(a*(1-a))*xi          
        weight = weight - lr * w_gradient
        b_gradient = (a-yi)*(a*(1-a))
        b = b - lr * b_gradient

        
#Run test images through the model to get predictions
        
prediction_array = [0 for x in range(len(test_images))]

for i in range(len(test_images)):
    x = test_images[i]
    z = x.T.dot(weight) + b
    a_predict = sigmoid(z)
    if a_predict > 0.5:
         a_predict = 1
    else:
         a_predict = 0
    prediction_array[i] = a_predict


#Check predictions and calculate accuracy    

count_correct = 0

for i in range(len(test_labels)):
    y = test_labels[i]
    if prediction_array[i] == 1 and test_labels[i] == 1:
        count_correct = count_correct + 1
    if prediction_array[i] == 0 and test_labels[i] == 0:
        count_correct = count_correct + 1
    accuracy = count_correct/(len(test_images))

print(count_correct) 
print(accuracy)

#The accuracy for #0 was: 90.1%
#The accuracy for #1 was: 97.7%
#The accuracy for #2 was: 89.6%
#The accuracy for #3 was: 93.6%
#The accuracy for #4 was: 90.1%
#The accuracy for #5 was: 91.0%
#The accuracy for #6 was: 90.3%
#The accuracy for #7 was: 89.6%
#The accuracy for #8 was: 90.1%
#The accuracy for #9 was: 89.8%
